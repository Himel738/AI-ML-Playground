# %%
print("Hello World")
# Out:
# The kernel failed to start as 'eq' could not be imported from 'consider renaming 'c:\\Users\\KutuMia20\\Documents\\GitHub\\python\\Code\\operator.py' since it has the same name as the standard library module named 'operator' and prevents importing that standard library module'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.
