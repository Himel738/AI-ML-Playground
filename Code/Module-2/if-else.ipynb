# %% [markdown]
# ## Conditional Statement In Python

# %%
age = 1

if(age >= 18):
    print("Can Vote and Apply for License")
elif(age <= 18):
    print("Can't")
# Out:
# Can't

# %%
raining = True
muddy = True
if raining:
    print("Take Umbrella")
    if muddy:
        print("Take Gumboots")
else:
    print("No need of Umbrella")
# Out:
# Take Umbrella
# Take Gumboots
