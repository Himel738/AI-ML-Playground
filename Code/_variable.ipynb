# %%
"""
A variable is a name given to memory location in a program
name = "Himel"
age = 23
price = 25.99

Data Type Primary
integer
string
float
boolean
None  a = None

"""

age = 23
price = 23.99
a = None
b = True

age2 = age

print(age)
print(price)
print(age2)

print(type(age))
print(type(price))
print(type(a))
print(type(b))
# Out:
# 23
# 23.99
# 23
# <class 'int'>
# <class 'float'>
# <class 'NoneType'>
# <class 'bool'>

# %%
name = "kutu Mia"
print(name)
print(type(name))
# Out:
# kutu Mia
# <class 'str'>
