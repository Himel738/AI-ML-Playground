# %% [markdown]
# # 🔹 Introduction to Pandas
#
# **Pandas** is a powerful Python library used for **data analysis and data manipulation**.
#
# It helps work with structured data like tables (rows & columns).
#
# ---
#
# ## 🔹 Key Features
# - Easy data handling and cleaning
# - Supports tabular data (like Excel sheets)
# - Fast and efficient operations
# - Built on top of NumPy
#
# ---
#
# ## 🔹 Core Data Structures
# - **Series** → 1D labeled array
# - **DataFrame** → 2D table (rows & columns)
#
# ---
#
# ## 🔹 Why Use Pandas?
# - Analyze large datasets easily
# - Perform filtering, grouping, and aggregation
# - Handle missing data
# - Widely used in Data Science & ML
#
# ---
#
# ## 🔹 Summary
#
# Pandas is used to **load, process, and analyze data efficiently in Python**.

# %% [markdown]
# ## Pandas Dataframe and series-(Single Row or Single Column)

# %%
import pandas as pd
# loading a csv file
df = pd.read_csv('student_data (1).csv')
print(df)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
student_id = df['StudentID']
print(student_id)
# Out:
# 0     PH1001
# 1     PH1002
# 2     PH1003
# 3     PH1004
# 4     PH1005
# 5     PH1006
# 6     PH1007
# 7     PH1008
# 8     PH1009
# 9     PH1010
# 10    PH1011
# 11    PH1012
# 12    PH1013
# 13    PH1014
# 14    PH1015
# 15    PH1016
# 16    PH1017
# 17    PH1018
# 18    PH1019
# 19    PH1020
# Name: StudentID, dtype: object

# %%
print(type(student_id))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# # 🔹 Working With Different File Types in Pandas
#
# Pandas allows you to **read and write data in multiple file formats**, making it very powerful for data analysis.
#
# ---
#
# ## 🔹 Common File Types
#
# ### 📄 CSV (Comma Separated Values)
# - Most commonly used format
# - Easy to read and write
#
# ```python
# df = pd.read_csv("data.csv")
# df.to_csv("output.csv", index=False)
# ```
#
# ---
#
# ### 📊 Excel Files
# - Used in business and reporting
#
# ```python
# df = pd.read_excel("data.xlsx")
# df.to_excel("output.xlsx", index=False)
# ```
#
# ---
#
# ### 🗂️ JSON Files
# - Used for web APIs and nested data
#
# ```python
# df = pd.read_json("data.json")
# df.to_json("output.json")
# ```
#
# ---
#
# ### 🗃️ Text Files
# - Custom delimiter-based files
#
# ```python
# df = pd.read_csv("data.txt", delimiter="\t")
# ```
# ---
# ## Parquet File
#
# ```python
# parquet_file = pd.read_parquet('File_name.parquet')
# print(parquet_file)
# ```
# ---
#
# ### 🗄️ SQL Databases
# - Read data directly from databases
#
# ```python
# import sqlite3
#
# conn = sqlite3.connect("data.db")
# df = pd.read_sql("SELECT * FROM table_name", conn)
# ```
#
# ---
#
# ## 🔹 Key Points
# - Supports multiple file formats
# - Easy import and export
# - Handles large datasets efficiently
# - Works well with real-world data sources
#
# ---
#
# ## 🔹 Why It’s Important
# - Data comes in different formats
# - Pandas helps unify and process them easily
# - Essential for data analysis workflows
#
# ---
#
# ## 🔹 Summary
#
# Pandas allows you to **work with various file types like CSV, Excel, JSON, and databases**, making data handling flexible and efficient.

# %% [markdown]
# ## Panda's Basic Functionalities

# %%
df = pd.read_csv('student_data (1).csv')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# First Kichu Value
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001       Alif Rahman                  85.0             85.0
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram

# %%
df.head(3)
# Out:
#   StudentID       FullName  Data Structure Marks  Algorithm Marks  \
# 0    PH1001    Alif Rahman                  85.0             85.0
# 1    PH1002  Fatima Akhter                  92.0             92.0
# 2    PH1003  Imran Hossain                  88.0             88.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 0          88.0        Completed     2024-01-15  Mr. Karim       Dhaka
# 1           NaN      In Progress     2024-01-20  Ms. Salma  Chattogram
# 2          85.0        Completed     2024-02-10  Mr. Karim       Dhaka

# %%
# last theke
df.tail()
# Out:
#    StudentID      FullName  Data Structure Marks  Algorithm Marks  \
# 15    PH1016  Ziaur Rahman                  94.0             94.0
# 16    PH1017   Afsana Mimi                  90.0             90.0
# 17    PH1018   Babul Ahmed                  88.0             88.0
# 18    PH1019  Faria Rahman                   NaN              NaN
# 19    PH1020    Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 15           NaN      In Progress     2024-08-21  Ms. Salma  Chattogram
# 16          93.0        Completed     2025-09-01  Mr. Karim       Dhaka
# 17          85.0        Completed     2025-09-05  Ms. Salma      Sylhet
# 18           NaN      Not Started     2025-09-15  Mr. David  Chattogram
# 19          89.0        Completed     2025-10-02  Ms. Salma       Dhaka

# %%
df.tail(3)
# Out:
#    StudentID      FullName  Data Structure Marks  Algorithm Marks  \
# 17    PH1018   Babul Ahmed                  88.0             88.0
# 18    PH1019  Faria Rahman                   NaN              NaN
# 19    PH1020    Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 17          85.0        Completed     2025-09-05  Ms. Salma      Sylhet
# 18           NaN      Not Started     2025-09-15  Mr. David  Chattogram
# 19          89.0        Completed     2025-10-02  Ms. Salma       Dhaka

# %%
# cdataframe_column
df.columns
# Out:
# Index(['StudentID', 'FullName', 'Data Structure Marks', 'Algorithm Marks',
#        'Python Marks', 'CompletionStatus', 'EnrollmentDate', 'Instructor',
#        'Location'],
#       dtype='object')

# %%
import numpy as np
col = np.array(df.columns)
print(col)
# Out:
# ['StudentID' 'FullName' 'Data Structure Marks' 'Algorithm Marks'
#  'Python Marks' 'CompletionStatus' 'EnrollmentDate' 'Instructor'
#  'Location']

# %%
# index
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
# information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   StudentID             20 non-null     object
#  1   FullName              20 non-null     object
#  2   Data Structure Marks  16 non-null     float64
#  3   Algorithm Marks       16 non-null     float64
#  4   Python Marks          15 non-null     float64
#  5   CompletionStatus      20 non-null     object
#  6   EnrollmentDate        20 non-null     object
#  7   Instructor            20 non-null     object
#  8   Location              20 non-null     object
# dtypes: float64(3), object(6)
# memory usage: 1.5+ KB

# %%
df.sample(10)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 18    PH1019      Faria Rahman                   NaN              NaN
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 19    PH1020        Nasir Khan                  86.0             86.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 18           NaN      Not Started     2025-09-15  Mr. David  Chattogram
# ...

# %%
df.sample(10)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 18    PH1019      Faria Rahman                   NaN              NaN
# 9     PH1010      Priya Sharma                  89.0             89.0
# 19    PH1020        Nasir Khan                  86.0             86.0
# 5     PH1006       Laila Begum                  75.0             75.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 4           95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
# ...

# %%
# statistical
df.describe() # -> depends on numerical value
# Out:
#        Data Structure Marks  Algorithm Marks  Python Marks
# count             16.000000        16.000000     15.000000
# mean              84.000000        84.000000     85.666667
# std                6.501282         6.501282      5.394000
# min               72.000000        72.000000     76.000000
# 25%               79.500000        79.500000     83.000000
# 50%               85.500000        85.500000     85.000000
# 75%               88.250000        88.250000     88.500000
# max               94.000000        94.000000     95.000000

# %% [markdown]
# ## Data Frame From inbuilt Data with Columns and index

# %%
my_list =[['Alice', 25], ['Bob', 30], ['Charlie', 40]]
list_df = pd.DataFrame(my_list, columns = ['Names', 'Age'], index = [1, 2, 3])
list_df
# Out:
#      Names  Age
# 1    Alice   25
# 2      Bob   30
# 3  Charlie   40

# %%
my_tuple =(('Alice', 25), ('Bob', 30), ('Charlie', 40))
tuple_df = pd.DataFrame(my_tuple, columns = ['Names', 'Age'], index = [1, 2, 3])
tuple_df
# Out:
#      Names  Age
# 1    Alice   25
# 2      Bob   30
# 3  Charlie   40

# %%
my_dict = {
    "Names": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 40]
}

dict_df = pd.DataFrame(my_dict, index=[1, 2, 3]) # Key as a columns
dict_df
# Out:
#      Names  Age
# 1    Alice   25
# 2      Bob   30
# 3  Charlie   40

# %%
my_dict = [
     {"Names": "Alice", "Age": 25},
     {"Names": "Bob", "Age": 30},
     {"Names": "Charlie", "Age": 40, "City" : "Dhaka"}
]

dict_df = pd.DataFrame(my_dict)
dict_df
# Out:
#      Names  Age   City
# 0    Alice   25    NaN
# 1      Bob   30    NaN
# 2  Charlie   40  Dhaka

# %% [markdown]
# ## Accesing Data With Index and Column

# %%
df['StudentID']
# Out:
# 0     PH1001
# 1     PH1002
# 2     PH1003
# 3     PH1004
# 4     PH1005
# 5     PH1006
# 6     PH1007
# 7     PH1008
# 8     PH1009
# 9     PH1010
# 10    PH1011
# 11    PH1012
# 12    PH1013
# 13    PH1014
# 14    PH1015
# 15    PH1016
# 16    PH1017
# 17    PH1018
# 18    PH1019
# 19    PH1020
# Name: StudentID, dtype: object

# %%
# df.loc[row_start, row_end : col_start, Col_end]
df.loc[0]
# Out:
# StudentID                    PH1001
# FullName                Alif Rahman
# Data Structure Marks           85.0
# Algorithm Marks                85.0
# Python Marks                   88.0
# CompletionStatus          Completed
# EnrollmentDate           2024-01-15
# Instructor                Mr. Karim
# Location                      Dhaka
# Name: 0, dtype: object

# %%
# multiple row
df.loc[[2, 3, 19]]
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 19    PH1020        Nasir Khan                  86.0             86.0
#
#     Python Marks CompletionStatus EnrollmentDate Instructor Location
# 2           85.0        Completed     2024-02-10  Mr. Karim    Dhaka
# 3           82.0        Completed     2024-02-12  Ms. Salma   Sylhet
# 19          89.0        Completed     2025-10-02  Ms. Salma    Dhaka

# %%
# range er sahajje multiple row
df.loc[3:7]
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
# 5    PH1006       Laila Begum                  75.0             75.0
# 6    PH1007    Mahmudul Hasan                  80.0             80.0
# 7    PH1008       Nadia Islam                  81.0             81.0
#
#    Python Marks CompletionStatus EnrollmentDate Instructor    Location
# 3          82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# 4          95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
# 5          78.0        Completed     2024-03-08  Ms. Salma    Rajshahi
# 6           NaN      In Progress     2024-04-01  Mr. Karim       Dhaka
# 7          85.0        Completed     2024-04-22  Ms. Salma  Chattogram

# %%
# Single Column
df.loc[:, ['Python Marks']]
# Out:
#     Python Marks
# 0           88.0
# 1            NaN
# 2           85.0
# 3           82.0
# 4           95.0
# 5           78.0
# 6            NaN
# 7           85.0
# 8           76.0
# 9           88.0
# 10          91.0
# 11          87.0
# 12          79.0
# 13           NaN
# 14          84.0
# 15           NaN
# 16          93.0
# 17          85.0
# 18           NaN
# 19          89.0

# %%
# multiple columns
df.loc[:, ['Python Marks', 'Algorithm Marks']]
# Out:
#     Python Marks  Algorithm Marks
# 0           88.0             85.0
# 1            NaN             92.0
# 2           85.0             88.0
# 3           82.0             78.0
# 4           95.0              NaN
# 5           78.0             75.0
# 6            NaN             80.0
# 7           85.0             81.0
# 8           76.0             72.0
# 9           88.0             89.0
# 10          91.0              NaN
# 11          87.0             85.0
# 12          79.0             75.0
# 13           NaN              NaN
# 14          84.0             86.0
# 15           NaN             94.0
# 16          93.0             90.0
# 17          85.0             88.0
# 18           NaN              NaN
# 19          89.0             86.0

# %%
df.loc[3:7,'CompletionStatus']
# Out:
# 3      Completed
# 4    In Progress
# 5      Completed
# 6    In Progress
# 7      Completed
# Name: CompletionStatus, dtype: object

# %% [markdown]
# ## Changing index and Columns and iloc

# %%
df_index = df.set_index('StudentID') # ->  inplace = True Will effect the real Data Frame
df_index
# Out:
#                    FullName  Data Structure Marks  Algorithm Marks  \
# StudentID
# PH1001          Alif Rahman                  85.0             85.0
# PH1002        Fatima Akhter                  92.0             92.0
# PH1003        Imran Hossain                  88.0             88.0
# PH1004     Jannatul Ferdous                  78.0             78.0
# PH1005          Kamal Uddin                   NaN              NaN
# PH1006          Laila Begum                  75.0             75.0
# PH1007       Mahmudul Hasan                  80.0             80.0
# PH1008          Nadia Islam                  81.0             81.0
# PH1009           Omar Faruq                  72.0             72.0
# PH1010         Priya Sharma                  89.0             89.0
# PH1011         Rahim Sheikh                   NaN              NaN
# PH1012      Sadia Chowdhury                  85.0             85.0
# PH1013         Tanvir Ahmed                  75.0             75.0
# ...

# %%
df_index.iloc[3:7]
# Out:
#                    FullName  Data Structure Marks  Algorithm Marks  \
# StudentID
# PH1004     Jannatul Ferdous                  78.0             78.0
# PH1005          Kamal Uddin                   NaN              NaN
# PH1006          Laila Begum                  75.0             75.0
# PH1007       Mahmudul Hasan                  80.0             80.0
#
#            Python Marks CompletionStatus EnrollmentDate Instructor    Location
# StudentID
# PH1004             82.0        Completed     2024-02-12  Ms. Salma      Sylhet
# PH1005             95.0      In Progress     2024-03-05  Mr. Karim  Chattogram
# PH1006             78.0        Completed     2024-03-08  Ms. Salma    Rajshahi
# PH1007              NaN      In Progress     2024-04-01  Mr. Karim       Dhaka

# %%
df_index.iloc[:, 1:3]
# Out:
#            Data Structure Marks  Algorithm Marks
# StudentID
# PH1001                     85.0             85.0
# PH1002                     92.0             92.0
# PH1003                     88.0             88.0
# PH1004                     78.0             78.0
# PH1005                      NaN              NaN
# PH1006                     75.0             75.0
# PH1007                     80.0             80.0
# PH1008                     81.0             81.0
# PH1009                     72.0             72.0
# PH1010                     89.0             89.0
# PH1011                      NaN              NaN
# PH1012                     85.0             85.0
# PH1013                     75.0             75.0
# PH1014                      NaN              NaN
# PH1015                     86.0             86.0
# PH1016                     94.0             94.0
# PH1017                     90.0             90.0
# PH1018                     88.0             88.0
# ...

# %%
df.rename(columns={'FullName': 'Full Name'})
# Out:
#    StudentID         Full Name  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %% [markdown]
# ## Dropping Rows and columns, assigning value and iteration

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df.drop(0, inplace=True)
df.drop('Instructor', axis = 1, inplace= True)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# ...

# %%
df.loc[1, 'Python Marks'] = 90
df.loc[1, 'CompletionStatus'] = "Completed"

df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
# 5    PH1006       Laila Begum                  75.0             75.0
#
#    Python Marks CompletionStatus EnrollmentDate    Location
# 1          90.0        Completed     2024-01-20  Chattogram
# 2          85.0        Completed     2024-02-10       Dhaka
# 3          82.0        Completed     2024-02-12      Sylhet
# 4          95.0      In Progress     2024-03-05  Chattogram
# 5          78.0        Completed     2024-03-08    Rajshahi

# %%
df.loc[1:3, 'Python Marks'] += 2
df.head()
# Out:
#   StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 1    PH1002     Fatima Akhter                  92.0             92.0
# 2    PH1003     Imran Hossain                  88.0             88.0
# 3    PH1004  Jannatul Ferdous                  78.0             78.0
# 4    PH1005       Kamal Uddin                   NaN              NaN
# 5    PH1006       Laila Begum                  75.0             75.0
#
#    Python Marks CompletionStatus EnrollmentDate    Location
# 1          92.0        Completed     2024-01-20  Chattogram
# 2          87.0        Completed     2024-02-10       Dhaka
# 3          84.0        Completed     2024-02-12      Sylhet
# 4          95.0      In Progress     2024-03-05  Chattogram
# 5          78.0        Completed     2024-03-08    Rajshahi

# %%
for i,series in df.iterrows():
    print(f"{i} : {series}")
# Out:
# 1 : StudentID                      PH1002
# FullName                Fatima Akhter
# Data Structure Marks             92.0
# Algorithm Marks                  92.0
# Python Marks                     92.0
# CompletionStatus            Completed
# EnrollmentDate             2024-01-20
# Location                   Chattogram
# Name: 1, dtype: object
# 2 : StudentID                      PH1003
# FullName                Imran Hossain
# Data Structure Marks             88.0
# Algorithm Marks                  88.0
# Python Marks                     87.0
# CompletionStatus            Completed
# EnrollmentDate             2024-02-10
# Location                        Dhaka
# Name: 2, dtype: object
# 3 : StudentID                         PH1004
# FullName                Jannatul Ferdous
# Data Structure Marks                78.0
# Algorithm Marks                     78.0
# Python Marks                        84.0
# CompletionStatus               Completed
# ...

# %%
for i in df.itertuples():
    print(i)
# Out:
# Pandas(Index=1, StudentID='PH1002', FullName='Fatima Akhter', _3=92.0, _4=92.0, _5=92.0, CompletionStatus='Completed', EnrollmentDate='2024-01-20', Location='Chattogram')
# Pandas(Index=2, StudentID='PH1003', FullName='Imran Hossain', _3=88.0, _4=88.0, _5=87.0, CompletionStatus='Completed', EnrollmentDate='2024-02-10', Location='Dhaka')
# Pandas(Index=3, StudentID='PH1004', FullName='Jannatul Ferdous', _3=78.0, _4=78.0, _5=84.0, CompletionStatus='Completed', EnrollmentDate='2024-02-12', Location='Sylhet')
# Pandas(Index=4, StudentID='PH1005', FullName='Kamal Uddin', _3=nan, _4=nan, _5=95.0, CompletionStatus='In Progress', EnrollmentDate='2024-03-05', Location='Chattogram')
# Pandas(Index=5, StudentID='PH1006', FullName='Laila Begum', _3=75.0, _4=75.0, _5=78.0, CompletionStatus='Completed', EnrollmentDate='2024-03-08', Location='Rajshahi')
# ...

# %% [markdown]
# ## Sorting a Df

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# ...

# %%
df_copy = df.sort_values('Data Structure Marks') # Ascending order
df_copy
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 8     PH1009        Omar Faruq                  72.0             72.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 19    PH1020        Nasir Khan                  86.0             86.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# ...

# %%
df_copy = df.sort_values('Data Structure Marks', ascending=False) # Ascending order
df_copy
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 15    PH1016      Ziaur Rahman                  94.0             94.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 19    PH1020        Nasir Khan                  86.0             86.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# ...

# %%
df_copy = df.sort_values(['Data Structure Marks','Python Marks'], ascending=False) # Ascending order
df_copy
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 15    PH1016      Ziaur Rahman                  94.0             94.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 19    PH1020        Nasir Khan                  86.0             86.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# ...

# %%
df_copy = df.sort_values(['Data Structure Marks','Python Marks'], ascending=[0, 1]) # 0 -> false and 1 -> True
df_copy
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 15    PH1016      Ziaur Rahman                  94.0             94.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 19    PH1020        Nasir Khan                  86.0             86.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# ...

# %% [markdown]
# ## Filtering DataBase on condition

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# ...
