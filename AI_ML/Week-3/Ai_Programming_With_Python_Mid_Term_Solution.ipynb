# %% [markdown]
# <a href="https://colab.research.google.com/github/Himel738/AI-ML-Playground/blob/main/AI_ML/Week-3/Ai_Programming_With_Python_Mid_Term_Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Registered Email: sohanurhimel@gmail.com

# %%
# You must run this code and use this dataset for all questions

import numpy as np
import pandas as pd

np.random.seed(24)

num_employees = 50  # you can increase this if needed

# Employee data
emp_ids = np.arange(101, 101 + num_employees)
emp_ages = np.random.randint(20, 55, num_employees)
emp_income = np.random.randint(35000, 95000, num_employees)

# Fixed set of roles (repetition allowed)
roles_list = [
    "HR Manager",
    "Software Developer",
    "Accountant",
    "Marketing Executive",
    "Sales Executive",
    "Backend Developer",
    "HR Executive",
    "Financial Analyst",
    "Digital Marketer",
    "Operations Manager"
]

emp_roles = np.random.choice(roles_list, num_employees)

# Create DataFrame
data = pd.DataFrame({
    "emp_id": emp_ids,
    "emp_age": emp_ages,
    "emp_salary": emp_income,
    "role": emp_roles
})

# Save dataset
data.to_csv("staff_data.csv", index=False)

# %% [markdown]
# Q1:

# %%
emp_data = np.genfromtxt('staff_data.csv', delimiter=',', skip_header = 1)
emp_ages = emp_data[:, 1]
# print(emp_ages)
emp_salary = emp_data[:, 2]
# print(emp_salary)

print(type(emp_ages))
print(type(emp_salary))

print(emp_ages.ndim)
print(emp_salary.ndim)

print(emp_ages.shape)
print(emp_salary.shape)

print(emp_ages.size)
print(emp_salary.size)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# 1
# 1
# (50,)
# (50,)
# 50
# 50

# %% [markdown]
# Q2:

# %%
maximum_salary = np.max(emp_salary)
minimum_salary = np.min(emp_salary)

average_salary = np.mean(emp_salary)

avearage_age = np.mean(emp_ages)

print(maximum_salary, minimum_salary, average_salary, avearage_age)
# Out:
# 94722.0 35452.0 68409.48 35.44

# %% [markdown]
# Q3:

# %%
emp_between_25_and_40 = np.where((emp_ages>=25) & (emp_ages <= 40) & (emp_salary > 50000))
print(emp_between_25_and_40)
satisfied_total_employee = np.count_nonzero((emp_ages>=25) & (emp_ages <= 40) & (emp_salary > 50000))
print(satisfied_total_employee)
# Out:
# (array([ 4,  5,  7,  9, 10, 12, 13, 14, 19, 23, 25, 26, 29, 37, 38, 39, 48]),)
# 17

# %% [markdown]
# Q4:

# %%
modified_emp_age = np.where(emp_ages < avearage_age, emp_ages + 4,emp_ages + 2)

print(emp_ages)
print(modified_emp_age)
print(avearage_age)
# Out:
# [54. 23. 20. 43. 37. 37. 21. 35. 24. 38. 31. 35. 29. 38. 27. 45. 51. 48.
#  20. 32. 51. 53. 21. 26. 53. 37. 26. 21. 45. 30. 20. 47. 53. 53. 23. 24.
#  21. 30. 27. 25. 39. 20. 47. 41. 22. 52. 42. 54. 31. 50.]
# [56. 27. 24. 45. 39. 39. 25. 39. 28. 40. 35. 39. 33. 40. 31. 47. 53. 50.
#  24. 36. 53. 55. 25. 30. 55. 39. 30. 25. 47. 34. 24. 49. 55. 55. 27. 28.
#  25. 34. 31. 29. 41. 24. 49. 43. 26. 54. 44. 56. 35. 52.]
# 35.44

# %% [markdown]
# Q5:

# %%
modified_salary = emp_salary + (emp_salary * 0.8)
After_increase_total_salary_empense = np.sum(modified_salary)
before_total_salary_empense = np.sum(emp_salary)

print(modified_salary)
print(After_increase_total_salary_empense)
print(before_total_salary_empense)

print(f"difference - {After_increase_total_salary_empense-before_total_salary_empense}")
# Out:
# [ 93105.   69291.   63813.6 148131.  129936.6 106047.  137086.2 167155.2
#  137079.  162889.2 123553.8  86542.2 102382.2 150627.6 170499.6 163873.8
#   88018.2 123739.2 113736.6 133462.8 136153.8  85820.4 138168.  141037.2
#  109051.2 143816.4 107427.6 129398.4  91954.8 132660.  148590.  128604.6
#  136980.  130084.2 131965.2 157370.4 169968.6 151538.4  93623.4 113986.8
#   79912.8 107100.   99941.4 105483.6 163429.2  73909.8 148195.8 131486.4
#  107508.6  90716.4]
# 6156853.2
# 3420474.0
# difference - 2736379.2

# %% [markdown]
# Q6:

# %%
staff_data = pd.read_csv('staff_data.csv')
print(staff_data.head(3))
print(staff_data.info())
print(staff_data.describe())
# Out:
#    emp_id  emp_age  emp_salary                role
# 0     101       54       51725          HR Manager
# 1     102       23       38495          Accountant
# 2     103       20       35452  Operations Manager
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      50 non-null     int64
#  1   emp_age     50 non-null     int64
#  2   emp_salary  50 non-null     int64
#  3   role        50 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 1.7+ KB
# None
#           emp_id    emp_age    emp_salary
# count   50.00000  50.000000     50.000000
# mean   125.50000  35.440000  68409.480000
# std     14.57738  11.768446  15727.122334
# min    101.00000  20.000000  35452.000000
# 25%    113.25000  24.250000  57309.750000
# 50%    125.50000  35.000000  72037.500000
# 75%    137.75000  46.500000  79512.000000
# ...

# %% [markdown]
# Q7:

# %%
filter_dataset = pd.DataFrame(staff_data, columns=['emp_id', 'emp_age','role'])
age_25_to_40 = filter_dataset[(filter_dataset['emp_age'] > 25) & (filter_dataset['emp_age'] <= 40)]
print(age_25_to_40)

sort_dataset = age_25_to_40.sort_values('emp_id')
print("ANother")
print(sort_dataset)
print("Another")
print(sort_dataset.tail(3))
# Out:
#     emp_id  emp_age                 role
# 4      105       37    Backend Developer
# 5      106       37           HR Manager
# 7      108       35      Sales Executive
# 9      110       38         HR Executive
# 10     111       31    Backend Developer
# 11     112       35  Marketing Executive
# 12     113       29      Sales Executive
# 13     114       38   Operations Manager
# 14     115       27     Digital Marketer
# 19     120       32    Backend Developer
# 23     124       26   Software Developer
# 25     126       37   Operations Manager
# 26     127       26     Digital Marketer
# 29     130       30           Accountant
# 37     138       30           Accountant
# 38     139       27           HR Manager
# 40     141       39  Marketing Executive
# 48     149       31     Digital Marketer
# ANother
#     emp_id  emp_age                 role
# 4      105       37    Backend Developer
# 5      106       37           HR Manager
# 7      108       35      Sales Executive
# ...

# %% [markdown]
# Q8:

# %%
hr_roles = staff_data.loc[staff_data['role'].str.contains('HR')]
print(hr_roles)
print("another")
print(len(hr_roles))
# Out:
#     emp_id  emp_age  emp_salary          role
# 0      101       54       51725    HR Manager
# 5      106       37       58915    HR Manager
# 9      110       38       90494  HR Executive
# 24     125       53       60584  HR Executive
# 27     128       21       71888  HR Executive
# 38     139       27       52013    HR Manager
# 42     143       47       55523  HR Executive
# 44     145       22       90794  HR Executive
# 45     146       52       41061    HR Manager
# another
# 9

# %%
Q9:

# %%
sort_data_frame = staff_data.sort_values(
    ['emp_age', 'emp_salary'],
    ascending=[1,0]
)
print(sort_data_frame.head(5))
# Out:
#     emp_id  emp_age  emp_salary                role
# 30     131       20       82550     Sales Executive
# 18     119       20       63187  Software Developer
# 41     142       20       59500    Digital Marketer
# 2      103       20       35452  Operations Manager
# 36     137       21       94427     Sales Executive

# %% [markdown]
# Q10:

# %%
staff_data['emp_salary'] = np.where(
    (staff_data['role'] == "Software Developer") |
    (staff_data['role'] == "Backend Developer"),
    (staff_data['emp_salary'] + (staff_data['emp_salary']*0.12)),
    (staff_data['emp_salary'] + (staff_data['emp_salary']*0.05))
    )
staff_data
# Out:
#     emp_id  emp_age  emp_salary                 role
# 0      101       54    54311.25           HR Manager
# 1      102       23    40419.75           Accountant
# 2      103       20    37224.60   Operations Manager
# 3      104       43    86409.75     Digital Marketer
# 4      105       37    80849.44    Backend Developer
# 5      106       37    61860.75           HR Manager
# 6      107       21    85298.08    Backend Developer
# 7      108       35    97507.20      Sales Executive
# 8      109       24    79962.75      Sales Executive
# 9      110       38    95018.70         HR Executive
# 10     111       31    76877.92    Backend Developer
# 11     112       35    50482.95  Marketing Executive
# 12     113       29    59722.95      Sales Executive
# 13     114       38    87866.10   Operations Manager
# 14     115       27    99458.10     Digital Marketer
# 15     116       45    95593.05    Financial Analyst
# 16     117       51    51343.95      Sales Executive
# ...
