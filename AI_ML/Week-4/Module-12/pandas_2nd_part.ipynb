# %% [markdown]
# ## Filtering On String

# %%
import pandas as pd
data = {
    "Name": [
        "Rahim Uddin", "Karim Hasan", "Ayesha Akter", "Nusrat Jahan",
        "Tanvir Ahmed", "Sadia Islam", "Imran Hossain", "Farhan Rahman",
        "Mitu Sultana", "Shakib Al Hasan", "Rafiq Islam", "Jannat Ara",
        "Arif Khan", "Sumaiya Rahman", "Mahmudul Hasan"
    ],
    "City": [
        "Dhaka", "Chattogram", "Khulna", "Rajshahi",
        "Sylhet", "Barishal", "Rangpur", "Dhaka",
        "Chattogram", "Khulna", "Rajshahi", "Sylhet",
        "Barishal", "Rangpur", "Dhaka"
    ],
    "Department": [
        "IT", "HR", "Finance", "Marketing",
        "IT", "Finance", "HR", "Marketing",
        "IT", "Finance", "HR", "Marketing",
        "IT", "Finance", "HR"
    ],
    "Salary": [
        55000, 48000, 62000, 53000,
        70000, 58000, 45000, 60000,
        67000, 75000, 47000, 52000,
        69000, 61000, 50000
    ]
}
df = pd.DataFrame(data)
df
# Out:
#                Name        City Department  Salary
# 0       Rahim Uddin       Dhaka         IT   55000
# 1       Karim Hasan  Chattogram         HR   48000
# 2      Ayesha Akter      Khulna    Finance   62000
# 3      Nusrat Jahan    Rajshahi  Marketing   53000
# 4      Tanvir Ahmed      Sylhet         IT   70000
# 5       Sadia Islam    Barishal    Finance   58000
# 6     Imran Hossain     Rangpur         HR   45000
# 7     Farhan Rahman       Dhaka  Marketing   60000
# 8      Mitu Sultana  Chattogram         IT   67000
# 9   Shakib Al Hasan      Khulna    Finance   75000
# 10      Rafiq Islam    Rajshahi         HR   47000
# 11       Jannat Ara      Sylhet  Marketing   52000
# 12        Arif Khan    Barishal         IT   69000
# 13   Sumaiya Rahman     Rangpur    Finance   61000
# 14   Mahmudul Hasan       Dhaka         HR   50000

# %%
df.loc[df['City'].str.contains("Dh")]
# Out:
#               Name   City Department  Salary
# 0      Rahim Uddin  Dhaka         IT   55000
# 7    Farhan Rahman  Dhaka  Marketing   60000
# 14  Mahmudul Hasan  Dhaka         HR   50000

# %%
df.loc[df['City'].str.contains("dh", case=False)] # Case Sensitivity
# Out:
#               Name   City Department  Salary
# 0      Rahim Uddin  Dhaka         IT   55000
# 7    Farhan Rahman  Dhaka  Marketing   60000
# 14  Mahmudul Hasan  Dhaka         HR   50000

# %%
df.loc[df['City'].str.contains(r"ch", case=False)] # Regular Expression- ^ch means only starts with ch
# Out:
#            Name        City Department  Salary
# 1   Karim Hasan  Chattogram         HR   48000
# 8  Mitu Sultana  Chattogram         IT   67000

# %%
# end with 'ka'
df.loc[df['City'].str.contains(r"ka$", case=False)]
# Out:
#               Name   City Department  Salary
# 0      Rahim Uddin  Dhaka         IT   55000
# 7    Farhan Rahman  Dhaka  Marketing   60000
# 14  Mahmudul Hasan  Dhaka         HR   50000

# %%
df.loc[df['Name'].str.contains(r"^[AEIOU]", case=False)]
# Out:
#              Name      City Department  Salary
# 2    Ayesha Akter    Khulna    Finance   62000
# 6   Imran Hossain   Rangpur         HR   45000
# 12      Arif Khan  Barishal         IT   69000

# %%
df.loc[df['City'].str.contains(r"Dh|Ch", case=False)]
# Out:
#               Name        City Department  Salary
# 0      Rahim Uddin       Dhaka         IT   55000
# 1      Karim Hasan  Chattogram         HR   48000
# 7    Farhan Rahman       Dhaka  Marketing   60000
# 8     Mitu Sultana  Chattogram         IT   67000
# 14  Mahmudul Hasan       Dhaka         HR   50000

# %% [markdown]
# ## Adding a New Column

# %%
df = pd.read_csv('student_data.csv')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# Adding a Column with constant valueab
df['Country'] = "Bangladesh"
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df['Total Marks'] = df['Data Structure Marks'] + df['Python Marks'] + df['Algorithm Marks']
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
import numpy as np
df['A+ in DS'] = np.where(df['Data Structure Marks'] > 90, 'A+', 'A')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df['Passed in DS'] = df['Data Structure Marks'] > 70
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df['First Name'] = df['FullName'].str.split(' ').str[0]
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df1 = pd.read_csv('student_data.csv') # Data Not Save Internally
df1
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df.to_csv('new_student_data.csv')

# %% [markdown]
# ## Checking duplicates and Null Values in DF

# %%
employees = {
    "Name": [
        "Rahim Uddin", "Karim Hasan", "Ayesha Akter", "Rahim Uddin",
        "Tanvir Ahmed", "Sadia Islam", "Imran Hossain", "Farhan Rahman",
        "Mitu Sultana", "Sadia Islam", "Rafiq Islam", "Jannat Ara",
        "Arif Khan", "Sumaiya Rahman", "Karim Hasan"
    ],
    "City": [
        "Dhaka", "Chattogram", "Khulna", "Dhaka",
        "Sylhet", "Barishal", "Rangpur", "Dhaka",
        "Chattogram", "Barishal", "Rajshahi", "Sylhet",
        "Barishal", "Rangpur", "Chattogram"
    ],
    "Department": [
        "IT", "HR", "Finance", "IT",
        "IT", "Finance", "HR", "Marketing",
        "IT", "Finance", "HR", "Marketing",
        "IT", "Finance", "HR"
    ],
    "Salary": [
        55000, 48000, 62000, 55000,
        70000, 58000, 45000, 60000,
        67000, 58000, 47000, 52000,
        69000, 61000, 48000
    ]
}
df = pd.DataFrame(employees)
df
# Out:
#               Name        City Department  Salary
# 0      Rahim Uddin       Dhaka         IT   55000
# 1      Karim Hasan  Chattogram         HR   48000
# 2     Ayesha Akter      Khulna    Finance   62000
# 3      Rahim Uddin       Dhaka         IT   55000
# 4     Tanvir Ahmed      Sylhet         IT   70000
# 5      Sadia Islam    Barishal    Finance   58000
# 6    Imran Hossain     Rangpur         HR   45000
# 7    Farhan Rahman       Dhaka  Marketing   60000
# 8     Mitu Sultana  Chattogram         IT   67000
# 9      Sadia Islam    Barishal    Finance   58000
# 10     Rafiq Islam    Rajshahi         HR   47000
# 11      Jannat Ara      Sylhet  Marketing   52000
# 12       Arif Khan    Barishal         IT   69000
# 13  Sumaiya Rahman     Rangpur    Finance   61000
# 14     Karim Hasan  Chattogram         HR   48000

# %%
df['Name'].unique()
# Out:
# array(['Rahim Uddin', 'Karim Hasan', 'Ayesha Akter', 'Tanvir Ahmed',
#        'Sadia Islam', 'Imran Hossain', 'Farhan Rahman', 'Mitu Sultana',
#        'Rafiq Islam', 'Jannat Ara', 'Arif Khan', 'Sumaiya Rahman'],
#       dtype=object)

# %%
len(df['Name'].unique())
# Out:
# 12

# %%
df1 = pd.read_csv('student_data.csv')
df1
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# Works on Only Series
df1['Data Structure Marks'].unique()
# Out:
# array([85., 92., 88., 78., nan, 75., 80., 81., 72., 89., 86., 94., 90.])

# %%
print(df1['Data Structure Marks'].nunique()) # --> Without Null Values
len(df1['Data Structure Marks'].unique())
# Out:
# 12
# 13

# %%
df1.nunique()
# Out:
# StudentID               20
# FullName                20
# Data Structure Marks    12
# Algorithm Marks         12
# Python Marks            12
# CompletionStatus         3
# EnrollmentDate          20
# Instructor               3
# Location                 5
# dtype: int64

# %% [markdown]
# ## Check Null Values

# %%
df1.isnull() # False means ---> no Null # True means ---> Null Exist
# Out:
#     StudentID  FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 0       False     False                 False            False         False
# 1       False     False                 False            False          True
# 2       False     False                 False            False         False
# 3       False     False                 False            False         False
# 4       False     False                  True             True         False
# 5       False     False                 False            False         False
# 6       False     False                 False            False          True
# 7       False     False                 False            False         False
# 8       False     False                 False            False         False
# 9       False     False                 False            False         False
# 10      False     False                  True             True         False
# ...

# %%
df1['Data Structure Marks'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# Name: Data Structure Marks, dtype: bool

# %%
df1['Data Structure Marks'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13    False
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# Name: Data Structure Marks, dtype: bool

# %%
df1['Data Structure Marks'].hasnans # if 1 Null is present
# Out:
# True

# %% [markdown]
# ## Handling Duplicate Value

# %%
print(df.duplicated())
print(df)
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# dtype: bool
#               Name        City Department  Salary
# 0      Rahim Uddin       Dhaka         IT   55000
# 1      Karim Hasan  Chattogram         HR   48000
# 2     Ayesha Akter      Khulna    Finance   62000
# 3      Rahim Uddin       Dhaka         IT   55000
# 4     Tanvir Ahmed      Sylhet         IT   70000
# 5      Sadia Islam    Barishal    Finance   58000
# 6    Imran Hossain     Rangpur         HR   45000
# 7    Farhan Rahman       Dhaka  Marketing   60000
# 8     Mitu Sultana  Chattogram         IT   67000
# 9      Sadia Islam    Barishal    Finance   58000
# 10     Rafiq Islam    Rajshahi         HR   47000
# 11      Jannat Ara      Sylhet  Marketing   52000
# 12       Arif Khan    Barishal         IT   69000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
## Deleting Duplicates
df.drop_duplicates() # return a copy
# Out:
#               Name        City Department  Salary
# 0      Rahim Uddin       Dhaka         IT   55000
# 1      Karim Hasan  Chattogram         HR   48000
# 2     Ayesha Akter      Khulna    Finance   62000
# 4     Tanvir Ahmed      Sylhet         IT   70000
# 5      Sadia Islam    Barishal    Finance   58000
# 6    Imran Hossain     Rangpur         HR   45000
# 7    Farhan Rahman       Dhaka  Marketing   60000
# 8     Mitu Sultana  Chattogram         IT   67000
# 10     Rafiq Islam    Rajshahi         HR   47000
# 11      Jannat Ara      Sylhet  Marketing   52000
# 12       Arif Khan    Barishal         IT   69000
# 13  Sumaiya Rahman     Rangpur    Finance   61000

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#               Name        City Department  Salary
# 0      Rahim Uddin       Dhaka         IT   55000
# 1      Karim Hasan  Chattogram         HR   48000
# 2     Ayesha Akter      Khulna    Finance   62000
# 4     Tanvir Ahmed      Sylhet         IT   70000
# 5      Sadia Islam    Barishal    Finance   58000
# 6    Imran Hossain     Rangpur         HR   45000
# 7    Farhan Rahman       Dhaka  Marketing   60000
# 8     Mitu Sultana  Chattogram         IT   67000
# 10     Rafiq Islam    Rajshahi         HR   47000
# 11      Jannat Ara      Sylhet  Marketing   52000
# 12       Arif Khan    Barishal         IT   69000
# 13  Sumaiya Rahman     Rangpur    Finance   61000

# %%
# Column Er Basis e Duplicate Delete
df.drop_duplicates(subset=['City'])
# Out:
#              Name        City Department  Salary
# 0     Rahim Uddin       Dhaka         IT   55000
# 1     Karim Hasan  Chattogram         HR   48000
# 2    Ayesha Akter      Khulna    Finance   62000
# 4    Tanvir Ahmed      Sylhet         IT   70000
# 5     Sadia Islam    Barishal    Finance   58000
# 6   Imran Hossain     Rangpur         HR   45000
# 10    Rafiq Islam    Rajshahi         HR   47000

# %%
df.drop_duplicates(subset=['City'], keep='last') # By Default First Thake
# Out:
#               Name        City Department  Salary
# 2     Ayesha Akter      Khulna    Finance   62000
# 7    Farhan Rahman       Dhaka  Marketing   60000
# 8     Mitu Sultana  Chattogram         IT   67000
# 10     Rafiq Islam    Rajshahi         HR   47000
# 11      Jannat Ara      Sylhet  Marketing   52000
# 12       Arif Khan    Barishal         IT   69000
# 13  Sumaiya Rahman     Rangpur    Finance   61000

# %% [markdown]
# ## Handling Null Values

# %%
df = pd.read_csv('student_data.csv')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df.dropna() # ---> Remove the column where Null is present
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# ...

# %%
df.dropna(how='all') # Delete All the Column have Null Values
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df.dropna(subset=['Python Marks'])
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# ...

# %%
df.dropna(subset=['Python Marks', 'Algorithm Marks'])
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# ...

# %%
df.fillna(0)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   0.0              0.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   0.0              0.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df['FullName'].fillna('Unknown')
# Out:
# 0          Alif Rahman
# 1        Fatima Akhter
# 2        Imran Hossain
# 3     Jannatul Ferdous
# 4          Kamal Uddin
# 5          Laila Begum
# 6       Mahmudul Hasan
# 7          Nadia Islam
# 8           Omar Faruq
# 9         Priya Sharma
# 10        Rahim Sheikh
# 11     Sadia Chowdhury
# 12        Tanvir Ahmed
# 13          Urmi Akter
# 14        Wahiduzzaman
# 15        Ziaur Rahman
# 16         Afsana Mimi
# 17         Babul Ahmed
# 18        Faria Rahman
# 19          Nasir Khan
# Name: FullName, dtype: object

# %%
df.fillna({'Python Marks': df['Python Marks'].mean()}, inplace=True)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %% [markdown]
# ## Statistical Functions in Pandas

# %%
# Sumation
df['Data Structure Marks'].sum()
# Out:
# np.float64(1344.0)

# %%
# Min and Max
print(df['Data Structure Marks'].max())
print(df['Data Structure Marks'].min())
# Out:
# 94.0
# 72.0

# %%
# Mean
df['Data Structure Marks'].mean()
# Out:
# np.float64(84.0)

# %%
# Median
df['Data Structure Marks'].median()
# Out:
# 85.5

# %%
# Mode
df['Data Structure Marks'].mode()
# Out:
# 0    75.0
# 1    85.0
# 2    86.0
# 3    88.0
# Name: Data Structure Marks, dtype: float64

# %%
# Standard Deviation
df['Data Structure Marks'].std()
# Out:
# 6.501281924871945

# %%
# Co-Relation Matrix
df[['Data Structure Marks', 'Algorithm Marks']].corr()
# Out:
#                       Data Structure Marks  Algorithm Marks
# Data Structure Marks                   1.0              1.0
# Algorithm Marks                        1.0              1.0

# %%
# Doing Column Wise
df[['Data Structure Marks', 'Python Marks']].sum()
# Out:
# Data Structure Marks    1344.000000
# Python Marks            1713.333333
# dtype: float64

# %%
# Row Wise
df[['Data Structure Marks', 'Python Marks']].sum(axis=1)
# Out:
# 0     173.000000
# 1     177.666667
# 2     173.000000
# 3     160.000000
# 4      95.000000
# 5     153.000000
# 6     165.666667
# 7     166.000000
# 8     148.000000
# 9     177.000000
# 10     91.000000
# 11    172.000000
# 12    154.000000
# 13     85.666667
# 14    170.000000
# 15    179.666667
# 16    183.000000
# 17    173.000000
# 18     85.666667
# 19    175.000000
# dtype: float64

# %%
df['Total Marks'] = df.iloc[::,2:5].sum(axis=1)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df.describe()
# Out:
#        Data Structure Marks  Algorithm Marks  Python Marks  Total Marks
# count             16.000000        16.000000     20.000000    20.000000
# mean              84.000000        84.000000     85.666667   220.066667
# std                6.501282         6.501282      4.630183    68.685962
# min               72.000000        72.000000     76.000000    85.666667
# 25%               79.500000        79.500000     84.750000   226.000000
# 50%               85.500000        85.500000     85.666667   251.500000
# 75%               88.250000        88.250000     88.000000   261.000000
# max               94.000000        94.000000     95.000000   273.666667

# %% [markdown]
# ## Apply Function in Df

# %%
# min max Scaling
mn = df['Total Marks'].min()
mx = df['Total Marks'].max()
df['Scaled Marks'] = df['Total Marks'].apply(lambda x : (x - mn)/(mx-mn)) 
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# Custom Built Function
def grading_system(marks):
    if marks >= 260:
        return 'A+'
    elif marks >= 250:
        return 'A'
    else:
        return 'A-'
        
df['Grade'] = df['Total Marks'].apply(grading_system)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
def marking_system(df):
    a = df['Data Structure Marks'] * 2
    b = df['Algorithm Marks'] * 3
    c = df['Python Marks'] * 4
    return a+b+c
df = df.fillna(0)
df['Exceptional Marks'] = df.apply(marking_system, axis=1)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   0.0              0.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   0.0              0.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %% [markdown]
# ## DateTime and TimeDelta

# %%
df = pd.read_csv('student_completed_data.csv')
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %%
df['EnrollmentDate']
# Out:
# 0     2024-09-01
# 1     2024-08-11
# 2     2024-05-08
# 3     2024-07-05
# 4     2024-02-01
# 5     2024-09-07
# 6     2024-06-07
# 7     2024-03-22
# 8     2024-02-12
# 9     2024-06-19
# 10    2024-03-14
# 11    2024-08-04
# 12    2024-06-07
# 13    2024-01-04
# 14    2024-02-22
# 15    2024-03-23
# 16    2024-01-18
# 17    2024-06-23
# 18    2024-04-19
# 19    2024-07-21
# Name: EnrollmentDate, dtype: object

# %%
df['EnrollmentDate'] = pd.to_datetime(df['EnrollmentDate'])
df['EnrollmentDate']
# Out:
# 0    2024-09-01
# 1    2024-08-11
# 2    2024-05-08
# 3    2024-07-05
# 4    2024-02-01
# 5    2024-09-07
# 6    2024-06-07
# 7    2024-03-22
# 8    2024-02-12
# 9    2024-06-19
# 10   2024-03-14
# 11   2024-08-04
# 12   2024-06-07
# 13   2024-01-04
# 14   2024-02-22
# 15   2024-03-23
# 16   2024-01-18
# 17   2024-06-23
# 18   2024-04-19
# 19   2024-07-21
# Name: EnrollmentDate, dtype: datetime64[ns]

# %%
df['Enrollment Year'] = df['EnrollmentDate'].dt.year
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %%
df['Enrollment Date'] = df['EnrollmentDate'].dt.day
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %%
df['FinishedDate'] = pd.to_datetime(df['FinishedDate'])

# %%
df['Total Course Time'] = df['FinishedDate'] - df['EnrollmentDate']
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %% [markdown]
# ## Group By in Panda's

# %%
import numpy as np
df.loc[df['FullName'] == 'Afsana Mimi', 'Total Marks'] = np.nan
df.loc[df['FullName'] == 'Sadia Chowdhury', 'Total Marks'] = np.nan
df.loc[df['FullName'] == 'Alif Rahman', 'Total Marks'] = np.nan
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %%
instructor_group = df.groupby('Instructor')
instructor_group

# %%
for instructor, df_ins in instructor_group:
    print(instructor)
    display(df_ins)
# Out:
# Mr. David
#    StudentID        FullName CompletionStatus EnrollmentDate FinishedDate  \
# 4     PH0005     Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006     Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007  Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 9     PH0010    Priya Sharma        Completed     2024-06-19   2024-08-19
# 12    PH0013    Tanvir Ahmed        Completed     2024-06-07   2024-08-03
# 13    PH0014      Urmi Akter        Completed     2024-01-04   2024-03-23
# 14    PH0015    Wahiduzzaman        Completed     2024-02-22   2024-05-16
# 16    PH0017     Afsana Mimi        Completed     2024-01-18   2024-03-16
# 17    PH0018     Babul Ahmed        Completed     2024-06-23   2024-09-20
#
#    Instructor    Location  Total Marks  Enrollment Year  Enrollment Date  \
# 4   Mr. David      Sylhet        254.0             2024                1
# ...

# %%
instructor_group.min()
# Out:
#            StudentID      FullName CompletionStatus EnrollmentDate  \
# Instructor
# Mr. David     PH0005   Afsana Mimi        Completed     2024-01-04
# Mr. Karim     PH0002  Faria Rahman        Completed     2024-02-12
# Ms. Salma     PH0001   Alif Rahman        Completed     2024-03-22
#
#            FinishedDate    Location  Total Marks  Enrollment Year  \
# Instructor
# Mr. David    2024-03-16  Chattogram        248.0             2024
# Mr. Karim    2024-06-08       Dhaka        253.0             2024
# Ms. Salma    2024-05-01       Dhaka        234.0             2024
#
#             Enrollment Date Total Course Time
# Instructor
# Mr. David                 1           43 days
# Mr. Karim                 4           80 days
# Ms. Salma                 1           40 days

# %%
instructor_group.describe()
# Out:
#            EnrollmentDate                                                      \
#                     count                           mean                  min
# Instructor
# Mr. David               9            2024-04-22 13:20:00  2024-01-04 00:00:00
# Mr. Karim               7  2024-05-30 03:25:42.857142784  2024-02-12 00:00:00
# Ms. Salma               4            2024-05-13 18:00:00  2024-03-22 00:00:00
#
#                                                                            \
#                             25%                  50%                  75%
# Instructor
# Mr. David   2024-02-01 00:00:00  2024-06-07 00:00:00  2024-06-19 00:00:00
# Mr. Karim   2024-04-01 00:00:00  2024-07-05 00:00:00  2024-07-28 00:00:00
# Ms. Salma   2024-03-22 18:00:00  2024-04-15 00:00:00  2024-06-06 00:00:00
#
#                                      FinishedDate  \
#                             max  std        count
# Instructor
# Mr. David   2024-09-07 00:00:00  NaN            9
# ...

# %%
mean_marks = instructor_group['Total Marks'].mean()
mean_marks
# Out:
# Instructor
# Mr. David    270.375000
# Mr. Karim    274.166667
# Ms. Salma    249.666667
# Name: Total Marks, dtype: float64

# %%
df['Total Marks']=df['Total Marks'].fillna(df['Instructor'].map(mean_marks))
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...
